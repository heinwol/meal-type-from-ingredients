# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

from toolz import *


import os
import pickle
import json

# %%
with open('foodie_favorites_dataset/first_reviews.json', 'r') as f:
    rewiews_lines = f.readlines() #json.load(f)

# %%
rewiews_first = json.loads(rewiews_lines[0])
rewiews_first['reviews'][5]
# Out:
# {'date': '2008-05-16',
#  'rating': 4,
#  'comment': 'The McDonalds of Cuban food, and I mean it in a good way. \xa0Its got fast service, decent food, reasonable prices (used to be even better). \xa0  We all know about the Roasted (Fried) Garlic Chicken...nuff said! \xa0Its great when you need a Cuban fix but you will never mistake it for top notch quality food. \xa0Gotta come through at least once a quarter.'}

# %%
with open('foodie_favorites_dataset/restaurants.json', 'r') as f:
    for _ in range(4):
        f.readline()
    restaurant_nth = f.readline()

# %%
for i in range(len(rewiews_first['reviews'])):
    print(rewiews_first['reviews'][i]['comment'])
    print('\n' + '-'*100 + '\n')
# Out:
# Coming here to eat, was like having a little piece of home:)  Although, everything on the menu is not of Cuban authenticity(maybe Cuban inspired) nevertheless the food was still delicioso.
#
# ----------------------------------------------------------------------------------------------------
#
# The roasted pork or garlic chicken wth rice, beans and plantains are to die for! BTW, a glass or three of sangria are also recommended with your meal, but beware because the drink will sneak in on you. I love this place and I wish I could come here 6-7 days a week.
#
# ----------------------------------------------------------------------------------------------------
#
# Excellent food, friendly staff, quick service for both pickup and eating there!  They are all around wonderful!  I can't recommend this place highly enough - my favorites are number 7a or 10 on the menu (depending on whether you like Chicken or Steak).  Give them a try, you won't be disappointed :)
#
# ...
